# %% [markdown]
# ### To do list
# - Look into the Embarked feature and fill null values------- Done
# - Fill Null values of the Cabin variable based on Fare
# - look into the age feature and fill null values
#
# - DO parameter testing and chose the best parameters,
#
# - train a model using random forrests, decision tree, logistic reg
# - Check the accuracy of the models and choose the best model
# - test the model and make predicions
#
#
# #### Blake's requirement
# - Titanic EDA: -Fare Scatterplot... add shape by class and color by cabin
# - Try to find a way to create a chart to display feature importance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('train.csv')

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Filling Embarked missing values. 
#Reseach suggests that these two individuals boarded the Titanic from Southampton

# %%
data['Embarked'] = data['Embarked'].fillna('S')

# %%
data.Embarked.isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# ### Filling missing values of Age Feature:

# %%
data.Age.isna().sum()
# Out:
# 177

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Convert Selected numeric values to float

data.loc[:,['Age','Pclass','SibSp','Fare','Parch']] = data.loc[:,['Age','Pclass','SibSp','Fare']].applymap(float)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### Filter Missing Age values of 1st class passengers who paid over 100

# %%
data[((data.Age.isna()) & (data.Pclass ==1) & (data.Fare >= 100))]
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 306          307         1       1
# 334          335         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex  Age  SibSp  \
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1
# 306                            Fleming, Miss. Margaret  female  NaN      0
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...  female  NaN      1
# 527                                 Farthing, Mr. John    male  NaN      0
# 557                                Robbins, Mr. Victor    male  NaN      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 31       0  PC 17569  146.5208   B78        C
# 306      0     17421  110.8833   NaN        C
# 334      0  PC 17611  133.6500   NaN        S
# 527      0  PC 17483  221.7792   C95        S
# 557      0  PC 17757  227.5250   NaN        C

# %% [markdown]
# - Some research into the above data provides the Age of the particular ndividuals when the Titanic sunk.
# - That data can be used to fill the missing values of the Age feature.

# %%
data.loc[31:31,'Age'].fillna(45.0,inplace=True)

# %%
data.loc[31:31,:]
# Out:
#     PassengerId  Survived  Pclass  \
# 31           32         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female  45.0      1
#
#     Parch    Ticket      Fare Cabin Embarked
# 31      0  PC 17569  146.5208   B78        C

# %%
data.loc[306:306,'Age'].fillna(42.2,inplace = True)

# %%
data.loc[306:306,:]
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 306          307         1       1  Fleming, Miss. Margaret  female  42.2
#
#      SibSp  Parch Ticket      Fare Cabin Embarked
# 306      0      0  17421  110.8833   NaN        C

# %%
data.loc[334:334,'Age'].fillna(42.4,inplace = True)

# %%
data.loc[334:334,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 334          335         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...  female  42.4      1
#
#      Parch    Ticket    Fare Cabin Embarked
# 334      0  PC 17611  133.65   NaN        S

# %%
data.loc[527:527,'Age'].fillna(48,inplace = True)

# %%
data.loc[527:527,:]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 527          528         0       1  Farthing, Mr. John  male  48.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 527      0  PC 17483  221.7792   C95        S

# %%
data.loc[557:557,'Age'].fillna(45, inplace = True)

# %%
data.loc[557:557,:]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 557          558         0       1  Robbins, Mr. Victor  male  45.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 557      0  PC 17757  227.525   NaN        C

# %%
### Now let's look at missing values for people who paid between 50 - 100

# %%
data[((data.Age.isna()) & (data.Fare >= 50) & (data.Fare <100))]
# Out:
#      PassengerId  Survived  Pclass  \
# 159          160         0       3
# 166          167         1       1
# 180          181         0       3
# 185          186         0       1
# 201          202         0       3
# 256          257         1       1
# 324          325         0       3
# 375          376         1       1
# 457          458         1       1
# 475          476         0       1
# 643          644         1       3
# 669          670         1       1
# 692          693         1       3
# 792          793         0       3
# 826          827         0       3
# 846          847         0       3
# 849          850         1       1
# 863          864         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 159                         Sage, Master. Thomas Henry    male  NaN      8
# 166             Chibnall, Mrs. (Edith Martha Bowerman)  female  NaN      0
# ...

# %%
### We could attemp to fill the missing Age values or these the same way above

# %%
data.loc[324:324,'Age'].fillna(44.6,inplace = True)

# %%
data.loc[324:324,:]
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 324          325         0       3  Sage, Mr. George John Jr  male  44.6
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked
# 324      8      2  CA. 2343  69.55   NaN        S

# %%
data.loc[159:159,'Age'].fillna(5,inplace = True)

data.loc[159:159,:]
# Out:
#      PassengerId  Survived  Pclass                        Name   Sex  Age  \
# 159          160         0       3  Sage, Master. Thomas Henry  male  5.0
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked
# 159      8      2  CA. 2343  69.55   NaN        S

# %%
data.loc[180:180,'Age'].fillna(7,inplace = True)

data.loc[180:180,:]
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 180          181         0       3  Sage, Miss. Constance Gladys  female  7.0
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked
# 180      8      2  CA. 2343  69.55   NaN        S

# %%
data.loc[201:201,'Age'].fillna(16.9,inplace = True)

data.loc[201:201,:]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 201          202         0       3  Sage, Mr. Frederick  male  16.9      8
#
#      Parch    Ticket   Fare Cabin Embarked
# 201      2  CA. 2343  69.55   NaN        S

# %%
data.loc[792:792,'Age'].fillna(20.8,inplace = True)

data.loc[792:792,:]
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 792          793         0       3  Sage, Miss. Stella Anna  female  20.8
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked
# 792      8      2  CA. 2343  69.55   NaN        S

# %%
data.loc[846:846,'Age'].fillna(18.4,inplace = True)

data.loc[846:846,:]
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 846          847         0       3  Sage, Mr. Douglas Bullen  male  18.4
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked
# 846      8      2  CA. 2343  69.55   NaN        S

# %%
data.loc[863:863,'Age'].fillna(14.7,inplace = True)

data.loc[863:863,:]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 863  14.7      8      2  CA. 2343  69.55   NaN        S

# %%
### Null value left 

data[((data.Age.isna()) & (data.Fare >= 50) & (data.Fare <100))]
# Out:
#      PassengerId  Survived  Pclass  \
# 166          167         1       1
# 185          186         0       1
# 256          257         1       1
# 375          376         1       1
# 457          458         1       1
# 475          476         0       1
# 643          644         1       3
# 669          670         1       1
# 692          693         1       3
# 826          827         0       3
# 849          850         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 166             Chibnall, Mrs. (Edith Martha Bowerman)  female  NaN      0
# 185                              Rood, Mr. Hugh Roscoe    male  NaN      0
# 256                     Thorne, Mrs. Gertrude Maybelle  female  NaN      0
# 375              Meyer, Mrs. Edgar Joseph (Leila Saks)  female  NaN      1
# 457                  Kenyon, Mrs. Frederick R (Marion)  female  NaN      1
# 475                        Clifford, Mr. George Quincy    male  NaN      0
# ...

# %%
data.loc[166:166,'Age'].fillna(48,inplace = True)

data.loc[166:166,:]
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 166          167         1       1  Chibnall, Mrs. (Edith Martha Bowerman)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 166  female  48.0      0      1  113505  55.0   E33        S

# %%
data.loc[185:185,'Age'].fillna(39,inplace = True)

data.loc[185:185,:]
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 185          186         0       1  Rood, Mr. Hugh Roscoe  male  39.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 185      0  113767  50.0   A32        S

# %%
data.loc[256:256,'Age'].fillna(37.2,inplace = True)

data.loc[256:256,:]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 256          257         1       1  Thorne, Mrs. Gertrude Maybelle  female
#
#       Age  SibSp  Parch    Ticket  Fare Cabin Embarked
# 256  37.2      0      0  PC 17585  79.2   NaN        C

# %%
data.loc[375:375,'Age'].fillna(25.6,inplace = True)

data.loc[375:375,:]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 375          376         1       1  Meyer, Mrs. Edgar Joseph (Leila Saks)
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 375  female  25.6      1      0  PC 17604  82.1708   NaN        C

# %%
data.loc[457:457,'Age'].fillna(41,inplace = True)

data.loc[457:457,:]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 457          458         1       1  Kenyon, Mrs. Frederick R (Marion)  female
#
#       Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 457  41.0      1      0  17464  51.8625   D21        S

# %%
data.loc[475:475,'Age'].fillna(40.4,inplace = True)

data.loc[475:475,:]
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 475          476         0       1  Clifford, Mr. George Quincy  male  40.4
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 475      0      0  110465  52.0   A14        S

# %%
data.loc[643:643,'Age'].fillna(32,inplace = True)

data.loc[643:643,:]
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 643          644         1       3  Foo, Mr. Choong  male  32.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 643   1601  56.4958   NaN        S

# %%
data.loc[669:669,'Age'].fillna(49.4,inplace = True)

data.loc[669:669,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 669          670         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 669  Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)  female  49.4      1
#
#      Parch Ticket  Fare Cabin Embarked
# 669      0  19996  52.0  C126        S

# %%
data.loc[692:692,'Age'].fillna(38,inplace = True)

data.loc[692:692,:]
# Out:
#      PassengerId  Survived  Pclass          Name   Sex   Age  SibSp  Parch  \
# 692          693         1       3  Lam, Mr. Ali  male  38.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 692   1601  56.4958   NaN        S

# %%
data.loc[826:826,'Age'].fillna(23,inplace = True)

data.loc[826:826,:]
# Out:
#      PassengerId  Survived  Pclass          Name   Sex   Age  SibSp  Parch  \
# 826          827         0       3  Lam, Mr. Len  male  23.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 826   1601  56.4958   NaN        S

# %%
data.loc[849:849,'Age'].fillna(46.2,inplace = True)

data.loc[849:849,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  46.2      1      0
#
#     Ticket     Fare Cabin Embarked
# 849  17453  89.1042   C92        C

# %%
### Check the missing values left in the age column

# %%
data[data.Age.isna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# ...

# %% [markdown]
# - There seems to be a mixure of 1st,2nd and 3rd class passengers, that have a missing age value.

# %%
## Check the Missing Age value for 2nd class females

data[((data.Age.isna()) & (data.Sex == 'female') & (data.Pclass ==2))]
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex  Age  \
# 303          304         1       2         Keane, Miss. Nora A  female  NaN
# 596          597         1       2  Leitch, Miss. Jessie Wills  female  NaN
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 303      0      0  226593  12.35  E101        Q
# 596      0      0  248727  33.00   NaN        S

# %%
data.loc[303:303,'Age'].fillna(46,inplace = True)

data.loc[303:303,:]
# Out:
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 303          304         1       2  Keane, Miss. Nora A  female  46.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 303      0  226593  12.35  E101        Q

# %%
data.loc[596:596,'Age'].fillna(31.5,inplace = True)

data.loc[596:596,:]
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 596          597         1       2  Leitch, Miss. Jessie Wills  female  31.5
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 596      0      0  248727  33.0   NaN        S

# %%
## Check the Missing Age value for 3rd class females

data[((data.Age.isna()) & (data.Sex == 'female') & (data.Pclass ==3))]
# Out:
#      PassengerId  Survived  Pclass  \
# 19            20         1       3
# 28            29         1       3
# 32            33         1       3
# 47            48         1       3
# 82            83         1       3
# 109          110         1       3
# 128          129         1       3
# 140          141         0       3
# 186          187         1       3
# 198          199         1       3
# 229          230         0       3
# 235          236         0       3
# 240          241         0       3
# 241          242         1       3
# 264          265         0       3
# 274          275         1       3
# 300          301         1       3
# 330          331         1       3
# 347          348         1       3
# 358          359         1       3
# 359          360         1       3
# 367          368         1       3
# 368          369         1       3
# 409          410         0       3
# 415          416         0       3
# ...

# %%
# Checking the mean and median Fare for Pax over 35

data.groupby(data.Age > 35).Fare.agg(['mean','median'])
# Out:
#             mean  median
# Age
# False  26.927509   13.00
# True   47.192762   26.55

# %%
# Checking the mean and the median Class for passengers over 35

data.groupby(data.Age > 35).Pclass.agg(['mean','median'])
# Out:
#            mean  median
# Age
# False  2.494689     3.0
# True   1.780172     1.5

# %%
# Checking the Mean and the median Age of the passengers who paid less than 10

data.groupby(data.Fare < 10).Age.agg(['mean','median'])
# Out:
#             mean  median
# Fare
# False  30.631312    30.0
# True   28.156441    25.0

# %%
# Filter the Mising values for 1st class

# %%
data[((data.Age.isna()) & (data.Pclass ==1))]
# Out:
#      PassengerId  Survived  Pclass  \
# 55            56         1       1
# 64            65         0       1
# 168          169         0       1
# 270          271         0       1
# 284          285         0       1
# 295          296         0       1
# 298          299         1       1
# 351          352         0       1
# 507          508         1       1
# 602          603         0       1
# 633          634         0       1
# 711          712         0       1
# 740          741         1       1
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
#
#                                               Name   Sex  Age  SibSp  Parch  \
# 55                               Woolner, Mr. Hugh  male  NaN      0      0
# 64                           Stewart, Mr. Albert A  male  NaN      0      0
# 168                            Baumann, Mr. John D  male  NaN      0      0
# ...

# %%
### Get dummy variables to Sex Column.

# %%
data = pd.get_dummies(data,columns=['Sex'],drop_first=True)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex_male'],
#       dtype='object')

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Sex_male         uint8
# dtype: object

# %%
data['Sex_male'] = data.Sex_male.astype(float)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Sex_male       float64
# dtype: object

# %%
# Males who survived in first class

data[((data.Survived ==1) & (data.Pclass ==1) & (data.Sex_male))]
# Out:
#      PassengerId  Survived  Pclass  \
# 23            24         1       1
# 55            56         1       1
# 97            98         1       1
# 187          188         1       1
# 209          210         1       1
# 224          225         1       1
# 248          249         1       1
# 298          299         1       1
# 305          306         1       1
# 370          371         1       1
# 390          391         1       1
# 430          431         1       1
# 445          446         1       1
# 447          448         1       1
# 449          450         1       1
# 453          454         1       1
# 460          461         1       1
# 484          485         1       1
# 507          508         1       1
# 512          513         1       1
# 550          551         1       1
# 572          573         1       1
# 587          588         1       1
# 599          600         1       1
# 604          605         1       1
# ...

# %%
# Males who survived in 3rd class That has a missing Age value 

data[((data.Survived ==1) & (data.Pclass ==3) & (data.Sex_male) & (data.Age.isna()))]
# Out:
#      PassengerId  Survived  Pclass  \
# 65            66         1       3
# 444          445         1       3
# 709          710         1       3
# 828          829         1       3
#
#                                                   Name  Age  SibSp  Parch  \
# 65                            Moubarek, Master. Gerios  NaN      1      1
# 444                  Johannesen-Bratthammer, Mr. Bernt  NaN      0      0
# 709  Moubarek, Master. Halim Gonios ("William George")  NaN      1      1
# 828                       McCormack, Mr. Thomas Joseph  NaN      0      0
#
#      Ticket     Fare Cabin Embarked  Sex_male
# 65     2661  15.2458   NaN        C       1.0
# 444   65306   8.1125   NaN        S       1.0
# 709    2661  15.2458   NaN        C       1.0
# 828  367228   7.7500   NaN        Q       1.0

# %%
data.loc[36:36,'Age'].fillna(18.9,inplace = True)

data.loc[36:36,:]
# Out:
#     PassengerId  Survived  Pclass              Name   Age  SibSp  Parch  \
# 36           37         1       3  Mamee, Mr. Hanna  18.9      0      0
#
#    Ticket    Fare Cabin Embarked  Sex_male
# 36   2677  7.2292   NaN        C       1.0

# %%
data.loc[107:107,'Age'].fillna(29,inplace = True)

data.loc[107:107,:]
# Out:
#      PassengerId  Survived  Pclass                    Name   Age  SibSp  \
# 107          108         1       3  Moss, Mr. Albert Johan  29.0      0
#
#      Parch  Ticket   Fare Cabin Embarked  Sex_male
# 107      0  312991  7.775   NaN        S       1.0

# %%
data.loc[301:301,'Age'].fillna(24.4,inplace = True)

data.loc[301:301,:]
# Out:
#      PassengerId  Survived  Pclass                Name   Age  SibSp  Parch  \
# 301          302         1       3  McCoy, Mr. Bernard  24.4      2      0
#
#      Ticket   Fare Cabin Embarked  Sex_male
# 301  367226  23.25   NaN        Q       1.0

# %%
data.loc[444:444,'Age'].fillna(29.5,inplace = True)

data.loc[444:444,:]
# Out:
#      PassengerId  Survived  Pclass                               Name   Age  \
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt  29.5
#
#      SibSp  Parch Ticket    Fare Cabin Embarked  Sex_male
# 444      0      0  65306  8.1125   NaN        S       1.0

# %%
data.loc[828:828,'Age'].fillna(19.4,inplace = True)

data.loc[828:828,:]
# Out:
#      PassengerId  Survived  Pclass                          Name   Age  SibSp  \
# 828          829         1       3  McCormack, Mr. Thomas Joseph  19.4      0
#
#      Parch  Ticket  Fare Cabin Embarked  Sex_male
# 828      0  367228  7.75   NaN        Q       1.0

# %%
## Now let's look int people who were travelling in first class with missing age value

# %%
data[((data.Age.isna()) & (data.Pclass ==1))]
# Out:
#      PassengerId  Survived  Pclass  \
# 55            56         1       1
# 64            65         0       1
# 168          169         0       1
# 270          271         0       1
# 284          285         0       1
# 295          296         0       1
# 298          299         1       1
# 351          352         0       1
# 507          508         1       1
# 602          603         0       1
# 633          634         0       1
# 711          712         0       1
# 740          741         1       1
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
#
#                                               Name  Age  SibSp  Parch  \
# 55                               Woolner, Mr. Hugh  NaN      0      0
# 64                           Stewart, Mr. Albert A  NaN      0      0
# 168                            Baumann, Mr. John D  NaN      0      0
# ...
